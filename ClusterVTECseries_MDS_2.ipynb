# %%
from scripts.ClusterTS_MDS import ClusterVTECDataMDS
from numpy import loadtxt, float64

from matplotlib import rcParams

rcParams.update({
    "text.usetex": True
})

# %%
PTEX_dissim = loadtxt("./data/PTEX_DTW_matrix.dat", dtype= float64, delimiter = ",")

# %%
MDS_methods = ("SMACOF-Dissim", "SMACOF-Dissim-Classic")
cluster_methods = ("K-Means", "Gaussian")
number_dims = tuple(range(2, 4))
number_clusters = tuple(range(2, 11))

TEC_ClusterSeries = ClusterVTECDataMDS(dissimilarity = PTEX_dissim)

metrics_SMACOF_DTW_results = dict()
metrics_SMACOF_DTW_Classic_results = dict()

# %%
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.metrics.cluster import silhouette_score, calinski_harabasz_score, davies_bouldin_score

def GetClusteringMetrics(Xc, num_clusters, cluster_method = "K-Means"):
    if cluster_method == "K-Means":
        KMeans_Cluster_TS = KMeans(n_clusters = num_clusters, init = "k-means++", max_iter = 500)
        Labels = KMeans_Cluster_TS.fit_predict(Xc)
        
    elif cluster_method == "Gaussian":
        GaussianMix_Cluster_TS = GaussianMixture(n_components = num_clusters, covariance_type = "full", init_params="k-means++", max_iter = 500)
        Labels = GaussianMix_Cluster_TS.fit_predict(Xc)

    SH_score_Xc = silhouette_score(Xc, Labels)
    CH_score_Xc = calinski_harabasz_score(Xc, Labels)
    DB_score_Xc = davies_bouldin_score(Xc, Labels)

    return {"Silhouette": SH_score_Xc, "Calinski–Harabasz ": CH_score_Xc, "Davies-Boulding":DB_score_Xc}

# %% [markdown]
# ## SMACOF-DTW y SMACOF-DTW inicializado con MDS clásico

# %%
for MDS_method in MDS_methods:
    for num_dims in number_dims:
        TEC_ClusterSeries.ComputeMDS(num_comps_mds = num_dims, method = MDS_method)

        for cluster_method in cluster_methods:
            for num_cluster in number_clusters:
                TEC_ClusterSeries.ClusterTSVectors(num_clusters = num_cluster, cluster_method = cluster_method)
                cluster_metrics = GetClusteringMetrics(TEC_ClusterSeries.Xc_TS, num_cluster, cluster_method)
                
                if MDS_method == MDS_methods[0]:
                    metrics_SMACOF_DTW_results[cluster_method + f"-{num_dims}-{num_cluster}"] = cluster_metrics
                else:
                    metrics_SMACOF_DTW_Classic_results[cluster_method + f"-{num_dims}-{num_cluster}"] = cluster_metrics
# Out:
# SMACOF-Dissim with 2 components has a stress value of 0.113955
# --Scores with K-Means clustering--
# SH coefficient = 0.654420508958958
# CH index = 7960.457651799231
# DB index = 0.5852175598883342
# --Total series for every cluster--
# 0 -> 2465
# 1 -> 1874
# --Scores with K-Means clustering--
# SH coefficient = 0.7126978676816403
# CH index = 12461.147698450788
# DB index = 0.46151520720005507
# --Total series for every cluster--
# 0 -> 659
# 1 -> 2449
# 2 -> 1231
# --Scores with K-Means clustering--
# SH coefficient = 0.5928501693973456
# CH index = 10614.91161169754
# DB index = 0.6016667398097423
# --Total series for every cluster--
# 0 -> 657
# 1 -> 649
# 2 -> 1215
# 3 -> 1818
# --Scores with K-Means clustering--
# SH coefficient = 0.5502585886889501
# CH index = 10213.663897125265
# DB index = 0.7166746153681329
# --Total series for every cluster--
# 0 -> 939
# 1 -> 1819
# 2 -> 645
# 3 -> 642
# 4 -> 294
# --Scores with K-Means clustering--
# SH coefficient = 0.5509977032638018
# CH index = 10000.36594303442
# DB index = 0.7826323635109308
# --Total series for every cluster--
# 0 -> 1816
# 1 -> 923
# 2 -> 581
# 3 -> 638
# 4 -> 73
# 5 -> 308
# --Scores with K-Means clustering--
# SH coefficient = 0.5286667944695443
# CH index = 9529.485020961436
# DB index = 0.7896505507554142
# --Total series for every cluster--
# 0 -> 1814
# 1 -> 731
# 2 -> 578
# 3 -> 638
# 4 -> 73
# 5 -> 42
# 6 -> 463
# --Scores with K-Means clustering--
# SH coefficient = 0.5192155863881777
# CH index = 9487.044729234174
# DB index = 0.7469638912077008
# --Total series for every cluster--
# 0 -> 259
# 1 -> 1814
# 2 -> 453
# 3 -> 348
# 4 -> 64
# 5 -> 639
# 6 -> 720
# 7 -> 42
# --Scores with K-Means clustering--
# SH coefficient = 0.5036498782495229
# CH index = 9117.081952485947
# DB index = 0.7569840713857512
# --Total series for every cluster--
# 0 -> 540
# 1 -> 1813
# 2 -> 348
# 3 -> 442
# 4 -> 254
# 5 -> 638
# 6 -> 21
# 7 -> 219
# 8 -> 64
# --Scores with K-Means clustering--
# SH coefficient = 0.45292467071209147
# CH index = 8378.060218576798
# DB index = 0.8768652424098837
# --Total series for every cluster--
# 0 -> 557
# 1 -> 59
# 2 -> 453
# 3 -> 354
# 4 -> 1547
# 5 -> 49
# 6 -> 704
# 7 -> 53
# 8 -> 352
# 9 -> 211
# --Scores with GaussianMix clustering--
# SH coefficient = 0.5513459046787469
# CH index = 5085.540878069287
# DB index = 0.6483738688660291
# --Total series for every cluster--
# 0 -> 2082
# 1 -> 2257
# --Scores with GaussianMix clustering--
# SH coefficient = 0.5546526879558663
# CH index = 5921.118216841576
# DB index = 0.6639672393468553
# --Total series for every cluster--
# 0 -> 1935
# 1 -> 1764
# 2 -> 640
# --Scores with GaussianMix clustering--
# SH coefficient = 0.5540426042428341
# CH index = 4463.416006371494
# DB index = 1.151338665273202
# --Total series for every cluster--
# 0 -> 2018
# 1 -> 1096
# 2 -> 475
# 3 -> 750
# --Scores with GaussianMix clustering--
# SH coefficient = 0.43843912995986284
# CH index = 4294.223933636396
# DB index = 1.6174409199212243
# --Total series for every cluster--
# 0 -> 1485
# 1 -> 1130
# 2 -> 493
# 3 -> 352
# 4 -> 879
# --Scores with GaussianMix clustering--
# SH coefficient = 0.41508354554892546
# CH index = 3563.0322307397555
# DB index = 3.3943068485377115
# --Total series for every cluster--
# 0 -> 1479
# 1 -> 456
# 2 -> 1091
# 3 -> 175
# 4 -> 877
# 5 -> 261
# --Scores with GaussianMix clustering--
# SH coefficient = 0.3053806160593814
# CH index = 3307.1154361387826
# DB index = 1.901201018185111
# --Total series for every cluster--
# 0 -> 315
# 1 -> 780
# 2 -> 1399
# 3 -> 497
# 4 -> 344
# 5 -> 353
# 6 -> 651
# --Scores with GaussianMix clustering--
# SH coefficient = 0.28764895378840516
# CH index = 4518.002569297477
# DB index = 1.937926061598633
# --Total series for every cluster--
# 0 -> 308
# 1 -> 713
# 2 -> 347
# 3 -> 250
# 4 -> 1339
# 5 -> 819
# 6 -> 418
# 7 -> 145
# --Scores with GaussianMix clustering--
# SH coefficient = 0.2907469180552746
# CH index = 4358.239060646807
# DB index = 2.119389718911573
# --Total series for every cluster--
# 0 -> 560
# 1 -> 255
# 2 -> 358
# 3 -> 287
# 4 -> 387
# 5 -> 139
# 6 -> 126
# 7 -> 809
# 8 -> 1418
# --Scores with GaussianMix clustering--
# SH coefficient = 0.2545026601564178
# CH index = 4185.093886078207
# DB index = 1.9402657695473535
# --Total series for every cluster--
# 0 -> 295
# 1 -> 633
# 2 -> 357
# 3 -> 160
# 4 -> 21
# 5 -> 401
# 6 -> 278
# 7 -> 1328
# 8 -> 584
# 9 -> 282
# SMACOF-Dissim with 3 components has a stress value of 0.067011
# --Scores with K-Means clustering--
# SH coefficient = 0.628542938811293
# CH index = 7086.803716821968
# DB index = 0.640162154361505
# --Total series for every cluster--
# 0 -> 2461
# 1 -> 1878
# --Scores with K-Means clustering--
# SH coefficient = 0.6784220093588328
# CH index = 8797.308972939863
# DB index = 0.566202428385623
# --Total series for every cluster--
# 0 -> 2452
# 1 -> 1274
# 2 -> 613
# --Scores with K-Means clustering--
# SH coefficient = 0.6271429214977771
# CH index = 7816.201087500317
# DB index = 0.7470679880748266
# --Total series for every cluster--
# 0 -> 2419
# 1 -> 602
# 2 -> 860
# 3 -> 458
# --Scores with K-Means clustering--
# SH coefficient = 0.5227178252406486
# CH index = 7382.66236506123
# DB index = 0.8016476985593745
# --Total series for every cluster--
# 0 -> 1847
# 1 -> 439
# 2 -> 599
# 3 -> 841
# 4 -> 613
# --Scores with K-Means clustering--
# SH coefficient = 0.6071132758086553
# CH index = 6092.807949105019
# DB index = 0.8167333439378298
# --Total series for every cluster--
# 0 -> 117
# 1 -> 2417
# 2 -> 688
# 3 -> 599
# 4 -> 34
# 5 -> 484
# --Scores with K-Means clustering--
# SH coefficient = 0.5071796692582914
# CH index = 6729.324406208208
# DB index = 0.8307480925275171
# --Total series for every cluster--
# 0 -> 1851
# 1 -> 465
# 2 -> 597
# 3 -> 608
# 4 -> 669
# 5 -> 119
# 6 -> 30
# --Scores with K-Means clustering--
# SH coefficient = 0.45506326305602446
# CH index = 6292.9175118664925
# DB index = 0.875031629349392
# --Total series for every cluster--
# 0 -> 857
# 1 -> 1587
# 2 -> 375
# 3 -> 371
# 4 -> 294
# 5 -> 243
# 6 -> 580
# 7 -> 32
# --Scores with K-Means clustering--
# SH coefficient = 0.43837012368112127
# CH index = 5873.635298187789
# DB index = 0.9189444413082387
# --Total series for every cluster--
# 0 -> 590
# 1 -> 398
# 2 -> 595
# 3 -> 29
# 4 -> 28
# 5 -> 1569
# 6 -> 206
# 7 -> 622
# 8 -> 302
# --Scores with K-Means clustering--
# SH coefficient = 0.42343290916569876
# CH index = 6045.883101688309
# DB index = 0.9216564457307831
# --Total series for every cluster--
# 0 -> 307
# 1 -> 1574
# 2 -> 377
# 3 -> 126
# 4 -> 586
# 5 -> 29
# 6 -> 229
# 7 -> 585
# 8 -> 229
# 9 -> 297
# --Scores with GaussianMix clustering--
# SH coefficient = 0.5337176827120409
# CH index = 4695.8024626412835
# DB index = 0.7031809909662136
# --Total series for every cluster--
# 0 -> 2237
# 1 -> 2102
# --Scores with GaussianMix clustering--
# SH coefficient = 0.5370351477817767
# CH index = 4696.533661348827
# DB index = 0.7176475880842804
# --Total series for every cluster--
# 0 -> 1780
# 1 -> 2001
# 2 -> 558
# --Scores with GaussianMix clustering--
# SH coefficient = 0.5429273498502765
# CH index = 4171.28125160932
# DB index = 1.2687881781207326
# --Total series for every cluster--
# 0 -> 1141
# 1 -> 2040
# 2 -> 669
# 3 -> 489
# --Scores with GaussianMix clustering--
# SH coefficient = 0.41275735095488686
# CH index = 3772.6174655817463
# DB index = 1.8685932632130757
# --Total series for every cluster--
# 0 -> 873
# 1 -> 501
# 2 -> 1158
# 3 -> 300
# 4 -> 1507
# --Scores with GaussianMix clustering--
# SH coefficient = 0.3676657853038046
# CH index = 3300.3280711482407
# DB index = 1.8692743185997538
# --Total series for every cluster--
# 0 -> 1490
# 1 -> 299
# 2 -> 1164
# 3 -> 229
# 4 -> 267
# 5 -> 890
# --Scores with GaussianMix clustering--
# SH coefficient = 0.28541661449550865
# CH index = 3049.314753844705
# DB index = 1.896828145922181
# --Total series for every cluster--
# 0 -> 587
# 1 -> 944
# 2 -> 248
# 3 -> 594
# 4 -> 1433
# 5 -> 215
# 6 -> 318
# --Scores with GaussianMix clustering--
# SH coefficient = 0.18829504062496807
# CH index = 3040.8009848575552
# DB index = 2.299064711955608
# --Total series for every cluster--
# 0 -> 475
# 1 -> 1004
# 2 -> 411
# 3 -> 627
# 4 -> 149
# 5 -> 895
# 6 -> 535
# 7 -> 243
# --Scores with GaussianMix clustering--
# SH coefficient = 0.30279785466622117
# CH index = 3094.0341707700445
# DB index = 1.5068387137739907
# --Total series for every cluster--
# 0 -> 1474
# 1 -> 281
# 2 -> 261
# 3 -> 143
# 4 -> 901
# 5 -> 306
# 6 -> 581
# 7 -> 316
# 8 -> 76
# --Scores with GaussianMix clustering--
# SH coefficient = 0.2885227002369195
# CH index = 2708.4660801789455
# DB index = 1.819845683557885
# --Total series for every cluster--
# 0 -> 881
# 1 -> 263
# 2 -> 521
# 3 -> 1487
# 4 -> 119
# 5 -> 88
# 6 -> 283
# 7 -> 262
# 8 -> 136
# 9 -> 299
# SMACOF-Dissim-Classic with 2 components has a stress value of 0.102658
# --Scores with K-Means clustering--
# SH coefficient = 0.6537198560939234
# CH index = 7846.523436522528
# DB index = 0.5818579141689645
# --Total series for every cluster--
# 0 -> 2464
# 1 -> 1875
# --Scores with K-Means clustering--
# SH coefficient = 0.7130878498634899
# CH index = 12206.891789048505
# DB index = 0.45084750597118867
# --Total series for every cluster--
# 0 -> 621
# 1 -> 2450
# 2 -> 1268
# --Scores with K-Means clustering--
# SH coefficient = 0.6879987693329397
# CH index = 11101.507031862906
# DB index = 0.5760823269004127
# --Total series for every cluster--
# 0 -> 2450
# 1 -> 1105
# 2 -> 611
# 3 -> 173
# --Scores with K-Means clustering--
# SH coefficient = 0.5830348591862471
# CH index = 11351.592583587233
# DB index = 0.6669152306571238
# --Total series for every cluster--
# 0 -> 642
# 1 -> 1097
# 2 -> 609
# 3 -> 1822
# 4 -> 169
# --Scores with K-Means clustering--
# SH coefficient = 0.5392703164105732
# CH index = 10831.162245664473
# DB index = 0.7056355951981059
# --Total series for every cluster--
# 0 -> 1819
# 1 -> 813
# 2 -> 415
# 3 -> 601
# 4 -> 643
# 5 -> 48
# --Scores with K-Means clustering--
# SH coefficient = 0.49315750379724155
# CH index = 9529.787863147416
# DB index = 0.8074763355965887
# --Total series for every cluster--
# 0 -> 169
# 1 -> 1558
# 2 -> 360
# 3 -> 576
# 4 -> 338
# 5 -> 1071
# 6 -> 267
# --Scores with K-Means clustering--
# SH coefficient = 0.4679014144957596
# CH index = 10077.71002163754
# DB index = 0.8049491113947371
# --Total series for every cluster--
# 0 -> 367
# 1 -> 575
# 2 -> 356
# 3 -> 267
# 4 -> 336
# 5 -> 1554
# 6 -> 845
# 7 -> 39
# --Scores with K-Means clustering--
# SH coefficient = 0.45874525276730804
# CH index = 9540.35738374847
# DB index = 0.7694920290807257
# --Total series for every cluster--
# 0 -> 1531
# 1 -> 819
# 2 -> 350
# 3 -> 43
# 4 -> 325
# 5 -> 575
# 6 -> 382
# 7 -> 272
# 8 -> 42
# --Scores with K-Means clustering--
# SH coefficient = 0.42141691350321503
# CH index = 9338.455463797354
# DB index = 0.8649365589914181
# --Total series for every cluster--
# 0 -> 614
# 1 -> 465
# 2 -> 265
# 3 -> 307
# 4 -> 355
# 5 -> 109
# 6 -> 364
# 7 -> 348
# 8 -> 30
# 9 -> 1482
# --Scores with GaussianMix clustering--
# SH coefficient = 0.5579869349073601
# CH index = 5185.443773031072
# DB index = 0.6406124228272969
# --Total series for every cluster--
# 0 -> 2102
# 1 -> 2237
# --Scores with GaussianMix clustering--
# SH coefficient = 0.5387328369152043
# CH index = 4917.097898310874
# DB index = 0.6088533367736427
# --Total series for every cluster--
# 0 -> 1890
# 1 -> 2009
# 2 -> 440
# --Scores with GaussianMix clustering--
# SH coefficient = 0.4535691190813328
# CH index = 5814.951654192231
# DB index = 0.9384046857214194
# --Total series for every cluster--
# 0 -> 375
# 1 -> 1720
# 2 -> 1490
# 3 -> 754
# --Scores with GaussianMix clustering--
# SH coefficient = 0.45254885219134794
# CH index = 4330.245912201777
# DB index = 2.6361437059074246
# --Total series for every cluster--
# 0 -> 1521
# 1 -> 329
# 2 -> 497
# 3 -> 856
# 4 -> 1136
# --Scores with GaussianMix clustering--
# SH coefficient = 0.3891479508910977
# CH index = 3914.2972751592056
# DB index = 2.259465722392566
# --Total series for every cluster--
# 0 -> 279
# 1 -> 862
# 2 -> 503
# 3 -> 875
# 4 -> 303
# 5 -> 1517
# --Scores with GaussianMix clustering--
# SH coefficient = 0.38239338733356054
# CH index = 4519.297729811148
# DB index = 1.7698402789709504
# --Total series for every cluster--
# 0 -> 318
# 1 -> 1517
# 2 -> 903
# 3 -> 870
# 4 -> 273
# 5 -> 165
# 6 -> 293
# --Scores with GaussianMix clustering--
# SH coefficient = 0.2778431455021838
# CH index = 3293.6319568005856
# DB index = 2.575733139900369
# --Total series for every cluster--
# 0 -> 1195
# 1 -> 874
# 2 -> 288
# 3 -> 300
# 4 -> 322
# 5 -> 188
# 6 -> 278
# 7 -> 894
# --Scores with GaussianMix clustering--
# SH coefficient = 0.36391195809623456
# CH index = 4425.840435602518
# DB index = 1.295864331487818
# --Total series for every cluster--
# 0 -> 274
# 1 -> 1508
# 2 -> 531
# 3 -> 861
# 4 -> 508
# 5 -> 30
# 6 -> 196
# 7 -> 286
# 8 -> 145
# --Scores with GaussianMix clustering--
# SH coefficient = 0.2870695477038253
# CH index = 3782.336345488759
# DB index = 1.6736840565991855
# --Total series for every cluster--
# 0 -> 1295
# 1 -> 309
# 2 -> 308
# 3 -> 324
# 4 -> 219
# 5 -> 109
# 6 -> 911
# 7 -> 306
# 8 -> 24
# 9 -> 534
# SMACOF-Dissim-Classic with 3 components has a stress value of 0.060265
# --Scores with K-Means clustering--
# SH coefficient = 0.626735845344769
# CH index = 7009.02390507464
# DB index = 0.6441601466481908
# --Total series for every cluster--
# 0 -> 2461
# 1 -> 1878
# --Scores with K-Means clustering--
# SH coefficient = 0.6754217010237661
# CH index = 8548.648121581733
# DB index = 0.5759938602985751
# --Total series for every cluster--
# 0 -> 1276
# 1 -> 2451
# 2 -> 612
# --Scores with K-Means clustering--
# SH coefficient = 0.6235268690248736
# CH index = 7610.316458084058
# DB index = 0.7455766276440267
# --Total series for every cluster--
# 0 -> 2416
# 1 -> 815
# 2 -> 599
# 3 -> 509
# --Scores with K-Means clustering--
# SH coefficient = 0.63604855735398
# CH index = 7243.972356179942
# DB index = 0.6961109026919894
# --Total series for every cluster--
# 0 -> 2424
# 1 -> 862
# 2 -> 599
# 3 -> 49
# 4 -> 405
# --Scores with K-Means clustering--
# SH coefficient = 0.5330096370467025
# CH index = 7636.487082778298
# DB index = 0.7511691000517647
# --Total series for every cluster--
# 0 -> 615
# 1 -> 597
# 2 -> 831
# 3 -> 48
# 4 -> 407
# 5 -> 1841
# --Scores with K-Means clustering--
# SH coefficient = 0.512250696430668
# CH index = 7244.788892456912
# DB index = 0.8220476244626072
# --Total series for every cluster--
# 0 -> 239
# 1 -> 1842
# 2 -> 824
# 3 -> 398
# 4 -> 612
# 5 -> 376
# 6 -> 48
# --Scores with K-Means clustering--
# SH coefficient = 0.49678185110681705
# CH index = 6431.75693814727
# DB index = 0.8504300742877533
# --Total series for every cluster--
# 0 -> 611
# 1 -> 554
# 2 -> 586
# 3 -> 152
# 4 -> 1844
# 5 -> 205
# 6 -> 46
# 7 -> 341
# --Scores with K-Means clustering--
# SH coefficient = 0.44843190055590376
# CH index = 5622.078985128995
# DB index = 0.8824960858566347
# --Total series for every cluster--
# 0 -> 400
# 1 -> 1426
# 2 -> 596
# 3 -> 823
# 4 -> 337
# 5 -> 20
# 6 -> 642
# 7 -> 34
# 8 -> 61
# --Scores with K-Means clustering--
# SH coefficient = 0.47893369052028
# CH index = 6084.0444464006805
# DB index = 0.9229550446621865
# --Total series for every cluster--
# 0 -> 553
# 1 -> 1844
# 2 -> 321
# 3 -> 153
# 4 -> 607
# 5 -> 45
# 6 -> 153
# 7 -> 134
# 8 -> 314
# 9 -> 215
# --Scores with GaussianMix clustering--
# SH coefficient = 0.5356248070188979
# CH index = 4728.32141824526
# DB index = 0.7044056220000416
# --Total series for every cluster--
# 0 -> 2112
# 1 -> 2227
# --Scores with GaussianMix clustering--
# SH coefficient = 0.531172359719634
# CH index = 4717.822093343322
# DB index = 0.7366619943039129
# --Total series for every cluster--
# 0 -> 596
# 1 -> 1966
# 2 -> 1777
# --Scores with GaussianMix clustering--
# SH coefficient = 0.5427087715955403
# CH index = 4290.756224145859
# DB index = 1.219503653578693
# --Total series for every cluster--
# 0 -> 653
# 1 -> 2028
# 2 -> 1155
# 3 -> 503
# --Scores with GaussianMix clustering--
# SH coefficient = 0.4445590266767931
# CH index = 3980.581807412747
# DB index = 1.4252410791792067
# --Total series for every cluster--
# 0 -> 421
# 1 -> 1902
# 2 -> 925
# 3 -> 615
# 4 -> 476
# --Scores with GaussianMix clustering--
# SH coefficient = 0.3570919506688725
# CH index = 3554.9050235765562
# DB index = 1.7957151272623488
# --Total series for every cluster--
# 0 -> 1484
# 1 -> 246
# 2 -> 521
# 3 -> 473
# 4 -> 898
# 5 -> 717
# --Scores with GaussianMix clustering--
# SH coefficient = 0.3245154018095367
# CH index = 3529.956443766753
# DB index = 1.9105555074633596
# --Total series for every cluster--
# 0 -> 447
# 1 -> 1450
# 2 -> 584
# 3 -> 137
# 4 -> 206
# 5 -> 909
# 6 -> 606
# --Scores with GaussianMix clustering--
# SH coefficient = 0.30609272532591275
# CH index = 3605.235979314766
# DB index = 1.4139785998145118
# --Total series for every cluster--
# 0 -> 934
# 1 -> 649
# 2 -> 248
# 3 -> 531
# 4 -> 73
# 5 -> 1426
# 6 -> 314
# 7 -> 164
# --Scores with GaussianMix clustering--
# SH coefficient = 0.15921537603997085
# CH index = 2989.002213549266
# DB index = 1.7113944691235017
# --Total series for every cluster--
# 0 -> 534
# 1 -> 943
# 2 -> 208
# 3 -> 111
# 4 -> 122
# 5 -> 497
# 6 -> 959
# 7 -> 334
# 8 -> 631
# --Scores with GaussianMix clustering--
# SH coefficient = 0.16820658509859612
# CH index = 2930.9206584768995
# DB index = 2.7244171320366193
# --Total series for every cluster--
# 0 -> 598
# 1 -> 932
# 2 -> 195
# 3 -> 59
# 4 -> 499
# 5 -> 945
# 6 -> 607
# 7 -> 305
# 8 -> 94
# 9 -> 105

# %% [markdown]
# ## Metricas de evaluación

# %%
from pandas import DataFrame

# Function to highlight min and max values within a block of N rows
def highlight_min_max(df_block):
    # Find min and max per column within the block
    min_vals = df_block.min()
    max_vals = df_block.max()

    # Create a DataFrame for styling with empty strings
    df_style = DataFrame('', index=df_block.index, columns=df_block.columns)

    # Apply the styles
    df_style[df_block == min_vals] = 'background-color: blue'  # Min
    df_style[df_block == max_vals] = 'background-color: red'  # Max

    return df_style

# Function to apply highlighting for blocks of N rows
def apply_highlight_in_blocks(df, N):
    # Create an empty DataFrame for styling
    style_df = DataFrame('', index=df.index, columns=df.columns)

    # Split DataFrame into blocks of N rows and apply highlight_min_max to each block
    for start in range(0, len(df), N):
        end = start + N
        block = df.iloc[start:end]
        
        # Apply the highlighting function to each block and assign it to the style DataFrame
        style_df.iloc[start:end] = highlight_min_max(block)

    return df.style.apply(lambda _: style_df, axis=None)

# %%
num_row_sep = len(number_clusters)

# %%
print("Metrics with DTW")
metrics_DTW_results = DataFrame(metrics_SMACOF_DTW_results)
styled_metrics_DTW = apply_highlight_in_blocks(metrics_DTW_results.T, num_row_sep)
styled_metrics_DTW
# Out:
# Metrics with DTW
# <style type="text/css">
# #T_2bcfd_row0_col1, #T_2bcfd_row1_col2, #T_2bcfd_row6_col0, #T_2bcfd_row9_col2, #T_2bcfd_row14_col0, #T_2bcfd_row14_col1, #T_2bcfd_row19_col2, #T_2bcfd_row26_col0, #T_2bcfd_row26_col1, #T_2bcfd_row27_col2, #T_2bcfd_row34_col0, #T_2bcfd_row35_col1 {
#   background-color: blue;
# }
# #T_2bcfd_row1_col0, #T_2bcfd_row1_col1, #T_2bcfd_row6_col2, #T_2bcfd_row10_col1, #T_2bcfd_row11_col0, #T_2bcfd_row16_col2, #T_2bcfd_row19_col0, #T_2bcfd_row19_col1, #T_2bcfd_row25_col2, #T_2bcfd_row28_col1, #T_2bcfd_row29_col0, #T_2bcfd_row33_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_2bcfd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bcfd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2bcfd_level0_col1" class="col_heading level0 col1" >Calinski–Harabasz </th>
#       <th id="T_2bcfd_level0_col2" class="col_heading level0 col2" >Davies-Boulding</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bcfd_level0_row0" class="row_heading level0 row0" >K-Means-2-2</th>
#       <td id="T_2bcfd_row0_col0" class="data row0 col0" >0.654421</td>
#       <td id="T_2bcfd_row0_col1" class="data row0 col1" >7960.457652</td>
#       <td id="T_2bcfd_row0_col2" class="data row0 col2" >0.585218</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row1" class="row_heading level0 row1" >K-Means-2-3</th>
#       <td id="T_2bcfd_row1_col0" class="data row1 col0" >0.712698</td>
#       <td id="T_2bcfd_row1_col1" class="data row1 col1" >12461.147698</td>
#       <td id="T_2bcfd_row1_col2" class="data row1 col2" >0.461515</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row2" class="row_heading level0 row2" >K-Means-2-4</th>
#       <td id="T_2bcfd_row2_col0" class="data row2 col0" >0.593012</td>
#       <td id="T_2bcfd_row2_col1" class="data row2 col1" >10614.925607</td>
#       <td id="T_2bcfd_row2_col2" class="data row2 col2" >0.601451</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row3" class="row_heading level0 row3" >K-Means-2-5</th>
#       <td id="T_2bcfd_row3_col0" class="data row3 col0" >0.648603</td>
#       <td id="T_2bcfd_row3_col1" class="data row3 col1" >8980.131474</td>
#       <td id="T_2bcfd_row3_col2" class="data row3 col2" >0.760041</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row4" class="row_heading level0 row4" >K-Means-2-6</th>
#       <td id="T_2bcfd_row4_col0" class="data row4 col0" >0.477615</td>
#       <td id="T_2bcfd_row4_col1" class="data row4 col1" >8730.742983</td>
#       <td id="T_2bcfd_row4_col2" class="data row4 col2" >0.812455</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row5" class="row_heading level0 row5" >K-Means-2-7</th>
#       <td id="T_2bcfd_row5_col0" class="data row5 col0" >0.538909</td>
#       <td id="T_2bcfd_row5_col1" class="data row5 col1" >9571.107356</td>
#       <td id="T_2bcfd_row5_col2" class="data row5 col2" >0.730396</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row6" class="row_heading level0 row6" >K-Means-2-8</th>
#       <td id="T_2bcfd_row6_col0" class="data row6 col0" >0.444853</td>
#       <td id="T_2bcfd_row6_col1" class="data row6 col1" >8252.777018</td>
#       <td id="T_2bcfd_row6_col2" class="data row6 col2" >0.917816</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row7" class="row_heading level0 row7" >K-Means-2-9</th>
#       <td id="T_2bcfd_row7_col0" class="data row7 col0" >0.524708</td>
#       <td id="T_2bcfd_row7_col1" class="data row7 col1" >9150.128604</td>
#       <td id="T_2bcfd_row7_col2" class="data row7 col2" >0.726461</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row8" class="row_heading level0 row8" >K-Means-2-10</th>
#       <td id="T_2bcfd_row8_col0" class="data row8 col0" >0.507096</td>
#       <td id="T_2bcfd_row8_col1" class="data row8 col1" >8837.322727</td>
#       <td id="T_2bcfd_row8_col2" class="data row8 col2" >0.752594</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row9" class="row_heading level0 row9" >Gaussian-2-2</th>
#       <td id="T_2bcfd_row9_col0" class="data row9 col0" >0.552952</td>
#       <td id="T_2bcfd_row9_col1" class="data row9 col1" >5110.710688</td>
#       <td id="T_2bcfd_row9_col2" class="data row9 col2" >0.647899</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row10" class="row_heading level0 row10" >Gaussian-2-3</th>
#       <td id="T_2bcfd_row10_col0" class="data row10 col0" >0.553784</td>
#       <td id="T_2bcfd_row10_col1" class="data row10 col1" >5905.454827</td>
#       <td id="T_2bcfd_row10_col2" class="data row10 col2" >0.664556</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row11" class="row_heading level0 row11" >Gaussian-2-4</th>
#       <td id="T_2bcfd_row11_col0" class="data row11 col0" >0.555905</td>
#       <td id="T_2bcfd_row11_col1" class="data row11 col1" >4500.178892</td>
#       <td id="T_2bcfd_row11_col2" class="data row11 col2" >1.147843</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row12" class="row_heading level0 row12" >Gaussian-2-5</th>
#       <td id="T_2bcfd_row12_col0" class="data row12 col0" >0.439269</td>
#       <td id="T_2bcfd_row12_col1" class="data row12 col1" >4288.021391</td>
#       <td id="T_2bcfd_row12_col2" class="data row12 col2" >1.599609</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row13" class="row_heading level0 row13" >Gaussian-2-6</th>
#       <td id="T_2bcfd_row13_col0" class="data row13 col0" >0.439507</td>
#       <td id="T_2bcfd_row13_col1" class="data row13 col1" >5348.648521</td>
#       <td id="T_2bcfd_row13_col2" class="data row13 col2" >1.701914</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row14" class="row_heading level0 row14" >Gaussian-2-7</th>
#       <td id="T_2bcfd_row14_col0" class="data row14 col0" >0.228334</td>
#       <td id="T_2bcfd_row14_col1" class="data row14 col1" >3202.776176</td>
#       <td id="T_2bcfd_row14_col2" class="data row14 col2" >1.844321</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row15" class="row_heading level0 row15" >Gaussian-2-8</th>
#       <td id="T_2bcfd_row15_col0" class="data row15 col0" >0.346754</td>
#       <td id="T_2bcfd_row15_col1" class="data row15 col1" >5076.090001</td>
#       <td id="T_2bcfd_row15_col2" class="data row15 col2" >1.213446</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row16" class="row_heading level0 row16" >Gaussian-2-9</th>
#       <td id="T_2bcfd_row16_col0" class="data row16 col0" >0.337468</td>
#       <td id="T_2bcfd_row16_col1" class="data row16 col1" >4547.763692</td>
#       <td id="T_2bcfd_row16_col2" class="data row16 col2" >3.079679</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row17" class="row_heading level0 row17" >Gaussian-2-10</th>
#       <td id="T_2bcfd_row17_col0" class="data row17 col0" >0.283319</td>
#       <td id="T_2bcfd_row17_col1" class="data row17 col1" >4469.807499</td>
#       <td id="T_2bcfd_row17_col2" class="data row17 col2" >2.614066</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row18" class="row_heading level0 row18" >K-Means-3-2</th>
#       <td id="T_2bcfd_row18_col0" class="data row18 col0" >0.628543</td>
#       <td id="T_2bcfd_row18_col1" class="data row18 col1" >7086.803717</td>
#       <td id="T_2bcfd_row18_col2" class="data row18 col2" >0.640162</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row19" class="row_heading level0 row19" >K-Means-3-3</th>
#       <td id="T_2bcfd_row19_col0" class="data row19 col0" >0.678422</td>
#       <td id="T_2bcfd_row19_col1" class="data row19 col1" >8797.308973</td>
#       <td id="T_2bcfd_row19_col2" class="data row19 col2" >0.566202</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row20" class="row_heading level0 row20" >K-Means-3-4</th>
#       <td id="T_2bcfd_row20_col0" class="data row20 col0" >0.627143</td>
#       <td id="T_2bcfd_row20_col1" class="data row20 col1" >7816.201088</td>
#       <td id="T_2bcfd_row20_col2" class="data row20 col2" >0.747068</td>
#     </tr>
#     <tr>
#       <th id="T_2bcfd_level0_row21" class="row_heading level0 row21" >K-Means-3-5</th>
#       <td id="T_2bcfd_row21_col0" class="data row21 col0" >0.636286</td>
#       <td id="T_2bcfd_row21_col1" class="da

# %%
print("Metrics with DTW-Classic")
metrics_DTW_Classic_results = DataFrame(metrics_SMACOF_DTW_Classic_results)
styled_metrics_DTW_Classic = apply_highlight_in_blocks(metrics_DTW_Classic_results.T, num_row_sep)
styled_metrics_DTW_Classic
# Out:
# Metrics with DTW-Classic
# <style type="text/css">
# #T_1870f_row0_col0, #T_1870f_row2_col1, #T_1870f_row7_col2, #T_1870f_row9_col0, #T_1870f_row9_col1, #T_1870f_row15_col2, #T_1870f_row19_col0, #T_1870f_row19_col1, #T_1870f_row25_col2, #T_1870f_row27_col1, #T_1870f_row29_col0, #T_1870f_row35_col2 {
#   background-color: red;
# }
# #T_1870f_row0_col2, #T_1870f_row1_col1, #T_1870f_row8_col0, #T_1870f_row10_col2, #T_1870f_row15_col0, #T_1870f_row16_col1, #T_1870f_row19_col2, #T_1870f_row21_col1, #T_1870f_row26_col0, #T_1870f_row27_col2, #T_1870f_row35_col0, #T_1870f_row35_col1 {
#   background-color: blue;
# }
# </style>
# <table id="T_1870f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1870f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1870f_level0_col1" class="col_heading level0 col1" >Calinski–Harabasz </th>
#       <th id="T_1870f_level0_col2" class="col_heading level0 col2" >Davies-Boulding</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1870f_level0_row0" class="row_heading level0 row0" >K-Means-2-2</th>
#       <td id="T_1870f_row0_col0" class="data row0 col0" >0.653720</td>
#       <td id="T_1870f_row0_col1" class="data row0 col1" >7846.523437</td>
#       <td id="T_1870f_row0_col2" class="data row0 col2" >0.581858</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row1" class="row_heading level0 row1" >K-Means-2-3</th>
#       <td id="T_1870f_row1_col0" class="data row1 col0" >0.479107</td>
#       <td id="T_1870f_row1_col1" class="data row1 col1" >4477.523620</td>
#       <td id="T_1870f_row1_col2" class="data row1 col2" >0.766499</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row2" class="row_heading level0 row2" >K-Means-2-4</th>
#       <td id="T_1870f_row2_col0" class="data row2 col0" >0.590922</td>
#       <td id="T_1870f_row2_col1" class="data row2 col1" >10339.389630</td>
#       <td id="T_1870f_row2_col2" class="data row2 col2" >0.606729</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row3" class="row_heading level0 row3" >K-Means-2-5</th>
#       <td id="T_1870f_row3_col0" class="data row3 col0" >0.602637</td>
#       <td id="T_1870f_row3_col1" class="data row3 col1" >9416.047899</td>
#       <td id="T_1870f_row3_col2" class="data row3 col2" >0.762699</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row4" class="row_heading level0 row4" >K-Means-2-6</th>
#       <td id="T_1870f_row4_col0" class="data row4 col0" >0.622196</td>
#       <td id="T_1870f_row4_col1" class="data row4 col1" >8584.356075</td>
#       <td id="T_1870f_row4_col2" class="data row4 col2" >0.700335</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row5" class="row_heading level0 row5" >K-Means-2-7</th>
#       <td id="T_1870f_row5_col0" class="data row5 col0" >0.499777</td>
#       <td id="T_1870f_row5_col1" class="data row5 col1" >9526.136141</td>
#       <td id="T_1870f_row5_col2" class="data row5 col2" >0.806444</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row6" class="row_heading level0 row6" >K-Means-2-8</th>
#       <td id="T_1870f_row6_col0" class="data row6 col0" >0.499978</td>
#       <td id="T_1870f_row6_col1" class="data row6 col1" >10101.356165</td>
#       <td id="T_1870f_row6_col2" class="data row6 col2" >0.792702</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row7" class="row_heading level0 row7" >K-Means-2-9</th>
#       <td id="T_1870f_row7_col0" class="data row7 col0" >0.493915</td>
#       <td id="T_1870f_row7_col1" class="data row7 col1" >9361.844092</td>
#       <td id="T_1870f_row7_col2" class="data row7 col2" >0.816709</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row8" class="row_heading level0 row8" >K-Means-2-10</th>
#       <td id="T_1870f_row8_col0" class="data row8 col0" >0.414915</td>
#       <td id="T_1870f_row8_col1" class="data row8 col1" >9554.983952</td>
#       <td id="T_1870f_row8_col2" class="data row8 col2" >0.806533</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row9" class="row_heading level0 row9" >Gaussian-2-2</th>
#       <td id="T_1870f_row9_col0" class="data row9 col0" >0.558942</td>
#       <td id="T_1870f_row9_col1" class="data row9 col1" >5201.478936</td>
#       <td id="T_1870f_row9_col2" class="data row9 col2" >0.640121</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row10" class="row_heading level0 row10" >Gaussian-2-3</th>
#       <td id="T_1870f_row10_col0" class="data row10 col0" >0.538550</td>
#       <td id="T_1870f_row10_col1" class="data row10 col1" >4916.272754</td>
#       <td id="T_1870f_row10_col2" class="data row10 col2" >0.609321</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row11" class="row_heading level0 row11" >Gaussian-2-4</th>
#       <td id="T_1870f_row11_col0" class="data row11 col0" >0.554804</td>
#       <td id="T_1870f_row11_col1" class="data row11 col1" >4447.762721</td>
#       <td id="T_1870f_row11_col2" class="data row11 col2" >1.277966</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row12" class="row_heading level0 row12" >Gaussian-2-5</th>
#       <td id="T_1870f_row12_col0" class="data row12 col0" >0.452451</td>
#       <td id="T_1870f_row12_col1" class="data row12 col1" >4332.374741</td>
#       <td id="T_1870f_row12_col2" class="data row12 col2" >2.643134</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row13" class="row_heading level0 row13" >Gaussian-2-6</th>
#       <td id="T_1870f_row13_col0" class="data row13 col0" >0.429160</td>
#       <td id="T_1870f_row13_col1" class="data row13 col1" >3988.195157</td>
#       <td id="T_1870f_row13_col2" class="data row13 col2" >2.193205</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row14" class="row_heading level0 row14" >Gaussian-2-7</th>
#       <td id="T_1870f_row14_col0" class="data row14 col0" >0.269338</td>
#       <td id="T_1870f_row14_col1" class="data row14 col1" >4280.332483</td>
#       <td id="T_1870f_row14_col2" class="data row14 col2" >4.472622</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row15" class="row_heading level0 row15" >Gaussian-2-8</th>
#       <td id="T_1870f_row15_col0" class="data row15 col0" >0.172540</td>
#       <td id="T_1870f_row15_col1" class="data row15 col1" >3036.096376</td>
#       <td id="T_1870f_row15_col2" class="data row15 col2" >8.381146</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row16" class="row_heading level0 row16" >Gaussian-2-9</th>
#       <td id="T_1870f_row16_col0" class="data row16 col0" >0.230317</td>
#       <td id="T_1870f_row16_col1" class="data row16 col1" >2676.103284</td>
#       <td id="T_1870f_row16_col2" class="data row16 col2" >3.745687</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row17" class="row_heading level0 row17" >Gaussian-2-10</th>
#       <td id="T_1870f_row17_col0" class="data row17 col0" >0.314632</td>
#       <td id="T_1870f_row17_col1" class="data row17 col1" >4359.958968</td>
#       <td id="T_1870f_row17_col2" class="data row17 col2" >1.331176</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row18" class="row_heading level0 row18" >K-Means-3-2</th>
#       <td id="T_1870f_row18_col0" class="data row18 col0" >0.626736</td>
#       <td id="T_1870f_row18_col1" class="data row18 col1" >7009.023905</td>
#       <td id="T_1870f_row18_col2" class="data row18 col2" >0.644160</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row19" class="row_heading level0 row19" >K-Means-3-3</th>
#       <td id="T_1870f_row19_col0" class="data row19 col0" >0.675422</td>
#       <td id="T_1870f_row19_col1" class="data row19 col1" >8548.648122</td>
#       <td id="T_1870f_row19_col2" class="data row19 col2" >0.575994</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row20" class="row_heading level0 row20" >K-Means-3-4</th>
#       <td id="T_1870f_row20_col0" class="data row20 col0" >0.621233</td>
#       <td id="T_1870f_row20_col1" class="data row20 col1" >7610.924947</td>
#       <td id="T_1870f_row20_col2" class="data row20 col2" >0.752181</td>
#     </tr>
#     <tr>
#       <th id="T_1870f_level0_row21" class="row_heading level0 row21" >K-Means-3-5</th>
#       <td id="T_1870f_row21_col0" class="data row21 col0" >0.593147</td>
#       <td id="T_1870f_row21_col1" class="dat
